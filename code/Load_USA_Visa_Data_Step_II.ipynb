# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
import datetime as dt

# %%
# file paths
out_file_path = "../output/"

# %% [markdown]
# # Attempting to calculate an adjusted Yearly wage

# %%
csv_file = f"{out_file_path}visa_intermediate.csv"
small_col_visa_df = pd.read_csv(filepath_or_buffer=csv_file, low_memory=False)
print(f"Input file name: {csv_file}")
# Out:
# Input file name: ../output/visa_intermediate.csv

# %%
# get 100 rows
hundred_rows = small_col_visa_df.iloc[0:100, ]

# %%
#How are they paid?
small_col_visa_df.wage_offer_unit_of_pay_9089.unique()
# Out:
# array(['yr', 'hr', 'mth', 'wk', 'bi', nan, 'Year', 'Hour', 'Week',
#        'Month', 'Bi-Weekly'], dtype=object)

# %%
def get_annual_wage(row):
    if row.wage_offer_unit_of_pay_9089 == 'hr':
        return float(row.wage_offer_from_9089) * 40 * 48
    elif row.wage_offer_unit_of_pay_9089 == 'wr':
        return float(row.wage_offer_from_9089) * 48
    elif row.wage_offer_unit_of_pay_9089 == 'mth':
        return float(row.wage_offer_from_9089) * 12

# %%
# for index, row in small_col_visa_df.iterrows():
#     if row["wage_offer_unit_of_pay_9089"] == "hr":
#         row["Adj_annual_wage"] = row["wage_offer_from_9089"] * 40 * 50

# add the column (Kannan)
small_col_visa_df['Adj_annual_wage'] = small_col_visa_df.apply(lambda row: get_annual_wage(row), axis=1)
small_col_visa_df['Adj_annual_wage'] = small_col_visa_df.apply(lambda row: get_annual_wage(row), axis=1)
small_col_visa_df.head(10)
# Out:
#          case_no    case_number        case_status class_of_admission  \
# 0  A-07323-97014  A-07323-97014          Certified                J-1
# 1  A-07332-99439  A-07332-99439             Denied                B-2
# 2  A-07333-99643  A-07333-99643          Certified               H-1B
# 3  A-07339-01930  A-07339-01930          Certified                B-2
# 4  A-07345-03565  A-07345-03565          Certified                L-1
# 5  A-07352-06288  A-07352-06288             Denied                EWI
# 6  A-07354-06926  A-07354-06926  Certified-Expired               H-1B
# 7  A-08004-10147  A-08004-10147             Denied                E-2
# 8  A-08004-10184  A-08004-10184          Certified               H-1B
# 9  A-08010-11785  A-08010-11785             Denied                E-2
#
#   country_of_citizenship country_of_citzenship decision_date employer_country  \
# 0                ARMENIA               ARMENIA    2012-02-01              NaN
# 1                 POLAND                POLAND    2011-12-21              NaN
# 2                  INDIA                 INDIA    2011-12-01              NaN
# 3            SOUTH KOREA           SOUTH KOREA    2011-12-01              NaN
# 4                 CANADA                CANADA    2012-01-26              NaN
# 5                ECUADOR               ECUADOR    2012-01-26              NaN
# 6                 MEXICO                MEXICO    2011-10-07              NaN
# 7                 CANADA                CANADA    2012-02-06              NaN
# 8                 CANADA                CANADA    2012-02-29              NaN
# 9               PAKISTAN              PAKISTAN    2012-03-30              NaN
#
#    employer_num_employees employer_postal_code  ... job_info_work_postal_code  \
# 0                     NaN              10010.0  ...                       NaN
# 1                     NaN               7072.0  ...                       NaN
# 2                     NaN              23059.0  ...                       NaN
# 3                     NaN              11354.0  ...                       NaN
# 4                     NaN              12204.0  ...                       NaN
# 5                     NaN               7072.0  ...                       NaN
# 6                     NaN              12180.0  ...                       NaN
# 7                     NaN              33069.0  ...                       NaN
# 8                     NaN              19808.0  ...                       NaN
# 9                     NaN              11208.0  ...                       NaN
#
#    job_info_work_state orig_file_date pw_amount_9089 pw_unit_of_pay_9089  \
# 0                   NY            NaN        75629.0                  yr
# 1                   NY            NaN        37024.0                  yr
# 2                   MD            NaN        47923.0                  yr
# 3                   NY            NaN          10.97                  hr
# 4                   NY            NaN        94890.0                  yr
# 5                   NY            NaN        37024.0                  yr
# 6                   NY            NaN       47083.33                  yr
# 7                   FL            NaN        36733.0                  yr
# 8                   TX            NaN        44824.0                  yr
# 9                   NY            NaN          12.86                  hr
#
#   wage_offer_from_9089 wage_offer_unit_of_pay_9089 wage_offered_from_9089  \
# 0              75629.0                          yr                    NaN
# 1              37024.0                          yr                    NaN
# 2              47923.0                          yr                    NaN
# 3                10.97                          hr                    NaN
# 4             100000.0                          yr                    NaN
# 5              37024.0                          yr                    NaN
# 6              47084.0                          yr                    NaN
# 7              36733.0                          yr                    NaN
# 8              44824.0                          yr                    NaN
# 9                12.86                          hr                    NaN
#
#   wage_offered_unit_of_pay_9089 Adj_annual_wage
# 0                           NaN             NaN
# 1                           NaN             NaN
# 2                           NaN             NaN
# 3                           NaN         21062.4
# 4                           NaN             NaN
# 5                           NaN             NaN
# 6                           NaN             NaN
# 7                           NaN             NaN
# 8                           NaN             NaN
# 9                           NaN         24691.2
#
# [10 rows x 40 columns]

# %%
csv_file = f"{out_file_path}visa_small4.csv"
small_col_visa_df.to_csv(csv_file, index=False, header=True)
print(f"Ouput file name: {csv_file}")
# Out:
# Ouput file name: ../output/visa_small4.csv

# %%
slim_visa_db =  small_col_visa_df[["case_number",
                                  "case_status",
                                  "class_of_admission",
                                  "country_of_citizenship",
                                  
                                  "decision_date",
                                  "employer_country",
                                  "employer_num_employees",
                                  "employer_postal_code",
                                  "employer_state",
                                  "employer_yr_estab",
                                  "foreign_worker_info_birth_country",
                                  
                                  "foreign_worker_info_education",
                                  "foreign_worker_info_major",
                                  "foreign_worker_info_postal_code",
                                  
                                  "foreign_worker_info_rel_occup_exp",
                                  
                                  "foreign_worker_info_state",
                                  "foreign_worker_info_training_comp",
                                  
                                  "foreign_worker_ownership_interest",
                                  
                                  "foreign_worker_yr_rel_edu_completed",
                                  
                                  "ji_offered_to_sec_j_foreign_worker",
                                  
                                  "job_info_education",
                                  "job_info_work_postal_code",
                                  "job_info_work_state",
                                  "orig_file_date",
                                  "pw_amount_9089",
                                  "pw_unit_of_pay_9089",
                                  "wage_offer_from_9089",
                                  "wage_offer_unit_of_pay_9089"]]
slim_visa_db.head()
# Out:
#      case_number case_status class_of_admission country_of_citizenship  \
# 0  A-07323-97014   Certified                J-1                ARMENIA
# 1  A-07332-99439      Denied                B-2                 POLAND
# 2  A-07333-99643   Certified               H-1B                  INDIA
# 3  A-07339-01930   Certified                B-2            SOUTH KOREA
# 4  A-07345-03565   Certified                L-1                 CANADA
#
#   decision_date employer_country  employer_num_employees employer_postal_code  \
# 0    2012-02-01              NaN                     NaN              10010.0
# 1    2011-12-21              NaN                     NaN               7072.0
# 2    2011-12-01              NaN                     NaN              23059.0
# 3    2011-12-01              NaN                     NaN              11354.0
# 4    2012-01-26              NaN                     NaN              12204.0
#
#   employer_state  employer_yr_estab  ... foreign_worker_yr_rel_edu_completed  \
# 0             NY                NaN  ...                                 NaN
# 1             NY                NaN  ...                                 NaN
# 2             VA                NaN  ...                                 NaN
# 3             NY                NaN  ...                                 NaN
# 4             NY                NaN  ...                                 NaN
#
#   ji_offered_to_sec_j_foreign_worker job_info_education  \
# 0                                NaN                NaN
# 1                                NaN                NaN
# 2                                NaN                NaN
# 3                                NaN                NaN
# 4                                NaN                NaN
#
#   job_info_work_postal_code job_info_work_state orig_file_date pw_amount_9089  \
# 0                       NaN                  NY            NaN        75629.0
# 1                       NaN                  NY            NaN        37024.0
# 2                       NaN                  MD            NaN        47923.0
# 3                       NaN                  NY            NaN          10.97
# 4                       NaN                  NY            NaN        94890.0
#
#   pw_unit_of_pay_9089  wage_offer_from_9089 wage_offer_unit_of_pay_9089
# 0                  yr               75629.0                          yr
# 1                  yr               37024.0                          yr
# 2                  yr               47923.0                          yr
# 3                  hr                 10.97                          hr
# 4                  yr              100000.0                          yr
#
# [5 rows x 28 columns]

# %%
slim_visa_db.set_index('case_number')
# Out:
#               case_status class_of_admission country_of_citizenship  \
# case_number
# A-07323-97014   Certified                J-1                ARMENIA
# A-07332-99439      Denied                B-2                 POLAND
# A-07333-99643   Certified               H-1B                  INDIA
# A-07339-01930   Certified                B-2            SOUTH KOREA
# A-07345-03565   Certified                L-1                 CANADA
# ...                   ...                ...                    ...
# A-16363-85407   Withdrawn                NaN            SOUTH KOREA
# A-16271-56745   Withdrawn                L-1                VIETNAM
# A-16354-82345   Withdrawn               H-1B                  INDIA
# A-16357-84250   Withdrawn                B-2            SOUTH KOREA
# A-16279-59292   Withdrawn               H-1B                  CHINA
#
#               decision_date          employer_country  employer_num_employees  \
# case_number
# A-07323-97014    2012-02-01                       NaN                     NaN
# A-07332-99439    2011-12-21                       NaN                     NaN
# A-07333-99643    2011-12-01                       NaN                     NaN
# A-07339-01930    2011-12-01                       NaN                     NaN
# A-07345-03565    2012-01-26                       NaN                     NaN
# ...                     ...                       ...                     ...
# A-16363-85407    2016-12-30  UNITED STATES OF AMERICA                     3.0
# A-16271-56745    2016-12-30  UNITED STATES OF AMERICA                 63000.0
# A-16354-82345    2016-12-30  UNITED STATES OF AMERICA                    33.0
# A-16357-84250    2016-12-30  UNITED STATES OF AMERICA                    16.0
# A-16279-59292    2016-12-30  UNITED STATES OF AMERICA                 54000.0
#
#               employer_postal_code employer_state  employer_yr_estab  \
# case_number
# A-07323-97014              10010.0             NY                NaN
# A-07332-99439               7072.0             NY                NaN
# A-07333-99643              23059.0             VA                NaN
# A-07339-01930              11354.0             NY                NaN
# A-07345-03565              12204.0             NY                NaN
# ...                            ...            ...                ...
# A-16363-85407                92802             CA             2014.0
# A-16271-56745                98052             WA             1975.0
# A-16354-82345                48197             MI             2010.0
# A-16357-84250                85018             AZ             2013.0
# A-16279-59292                95052             CA             1968.0
#
#               foreign_worker_info_birth_country  ...  \
# case_number                                      ...
# A-07323-97014                               NaN  ...
# A-07332-99439                               NaN  ...
# A-07333-99643                               NaN  ...
# A-07339-01930                               NaN  ...
# A-07345-03565                               NaN  ...
# ...                                         ...  ...
# A-16363-85407                       SOUTH KOREA  ...
# A-16271-56745                           VIETNAM  ...
# A-16354-82345                             INDIA  ...
# A-16357-84250                       SOUTH KOREA  ...
# A-16279-59292                             CHINA  ...
#
#               foreign_worker_yr_rel_edu_completed  \
# case_number
# A-07323-97014                                 NaN
# A-07332-99439                                 NaN
# A-07333-99643                                 NaN
# A-07339-01930                                 NaN
# A-07345-03565                                 NaN
# ...                                           ...
# A-16363-85407                              1995.0
# A-16271-56745                              2006.0
# A-16354-82345                              2013.0
# A-16357-84250                                 NaN
# A-16279-59292                              2016.0
#
#               ji_offered_to_sec_j_foreign_worker job_info_education  \
# case_number
# A-07323-97014                                NaN                NaN
# A-07332-99439                                NaN                NaN
# A-07333-99643                                NaN                NaN
# A-07339-01930                                NaN                NaN
# A-07345-03565                                NaN                NaN
# ...                                          ...                ...
# A-16363-85407                                  Y        Associate's
# A-16271-56745                                  Y           Master's
# A-16354-82345                                  Y           Master's
# A-16357-84250                                  Y               None
# A-16279-59292                                  Y           Master's
#
#               job_info_work_postal_code job_info_work_state orig_file_date  \
# case_number
# A-07323-97014                       NaN                  NY            NaN
# A-07332-99439                       NaN                  NY            NaN
# A-07333-99643                       NaN                  MD            NaN
# A-07339-01930                       NaN                  NY            NaN
# A-07345-03565                       NaN                  NY            NaN
# ...                                 ...                 ...            ...
# A-16363-85407                     92802                  CA            NaN
# A-16271-56745                     02142                  MA            NaN
# A-16354-82345                     48197                  MI            NaN
# A-16357-84250                     85018                  AZ            NaN
# A-16279-59292                     80528                  CO            NaN
#
#               pw_amount_9089  pw_unit_of_pay_9089 wage_offer_from_9089  \
# case_number
# A-07323-97014        75629.0                   yr              75629.0
# A-07332-99439        37024.0                   yr              37024.0
# A-07333-99643        47923.0                   yr              47923.0
# A-07339-01930          10.97                   hr                10.97
# A-07345-03565        94890.0                   yr             100000.0
# ...                      ...                  ...                  ...
# A-16363-85407      28,330.00                 Year            28,330.00
# A-16271-56745     107,744.00                 Year           122,000.00
# A-16354-82345      79,082.00                 Year            79,082.00
# A-16357-84250      37,981.00                 Year            37,981.00
# A-16279-59292      84,926.00                 Year            84,926.00
#
#               wage_offer_unit_of_pay_9089
# case_number
# A-07323-97014                          yr
# A-07332-99439                          yr
# A-07333-99643                          yr
# A-07339-01930                          hr
# A-07345-03565                          yr
# ...                                   ...
# A-16363-85407                        Year
# A-16271-56745                        Year
# A-16354-82345                        Year
# A-16357-84250                        Year
# A-16279-59292                        Year
#
# [374362 rows x 27 columns]

# %%
csv_file = f"{out_file_path}slim_visa_db.csv"
print(f"Ouput file name: {csv_file}")
slim_visa_db.to_csv(csv_file, index=False, header=True)
# Out:
# Ouput file name: ../output/slim_visa_db.csv

# %% [markdown]
# # Load the data to Database

# %%
# Kannan - added postgres_port
from config import postgres_password
from config import postgres_port
rds_connection_string = f"postgres:{postgres_password}@localhost:{postgres_port}/ETL_Project"
print(rds_connection_string)
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()

# %%
engine.execute('DELETE from "visa_data"')
result = engine.execute('SELECT * FROM "visa_data"')
slim_visa_db.to_sql(name='visa_data', con=engine, if_exists='append', index=False)

# %%
# further cleaning of the data

for index, row in small_col_visa_df.iterrows():
    df['case_number'].fillna(df['case_no'])
    
    if pd.isnull(row['case_number']):
        row['caseNumber'] = row['case_no']

    elif pd.notnull(row['case_number']):
        row['caseNumber'] = row['case_number']
        
    elif pd.isnull(row['country_of_citizenship']):
        row['countryCitizenship'] = row['country_of_citzenship']

    else:
        row['countryCitizenship'] = row['country_of_citizenship']
    
        
small_col_visa_df[["country_of_citizenship","country_of_citzenship","countryCitizenship"]].head()
     
# pd.notnull(row['country_of_citizenship'])

# %%
#Country of Citizenship

for index, row in small_col_visa_df.iterrows():
    if pd.isnull(row['country_of_citizenship']):
        row['countryCitizenship'] = row['country_of_citzenship']

    else:
        row['countryCitizenship'] = row['country_of_citizenship']
        
small_col_visa_df[["country_of_citizenship","country_of_citzenship","countryCitizenship"]].head()

# %%
#Foreign Worker Birth Country

for index, row in small_col_visa_df.iterrows():
    if pd.isnull(row['foreign_worker_info_birth_country']):
        row['birthCountry'] = row['fw_info_birth_country']

    else:
        row['birthCountry'] = row['foreign_worker_info_birth_country']
        
small_col_visa_df[["foreign_worker_info_birth_country", "fw_info_birth_country", "birthCountry"]].head()
